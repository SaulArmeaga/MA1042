# %% [markdown]
# <a href="https://colab.research.google.com/github/SaulArmeaga/MA1042/blob/main/Equipo1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **texto en negrita**# Integrantes

# %% [markdown]
# 1.   Andrés Deandar
# 2.   Erik Tovar
# 3.   Kleber Lugo Alcantara
# 4.   Beatriz Gonzales

# %% [markdown]
# # Contexto del proyecto

# %% [markdown]
# Este programa hablo sobre la calidad del aire a lo largo de los ultimos 6 años (registros desde el 2017-2022) publicados en el portal de datos de madrid, medimos altura y la calidad del aire en este programa. Sobre todo por su facilidad de graficar y tener un pie dentro de la noción del problema y como programarlo.

# %% [markdown]
# #Programa

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from google.colab import drive
import os

# Mount Google Drive
drive.mount('/content/drive')

# Change current directory to where the file is located
os.chdir('/content/drive/MyDrive/')

df_calidad_del_aire = pd.read_csv('ABT_CALIDAD_AIRE.csv')
df_calidad_del_aire
df_calidad_del_aire.isna().sum()
df_calidad_del_aire['Calidad_NO2'].isna().sum()
df_calidad_del_aire['Calidad_NO2'][df_calidad_del_aire['Calidad_NO2'].isna()]

conteo_altitud=df_calidad_del_aire['ALTITUD'].value_counts()
print(conteo_vis_km)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 10.0    57640
# 9.0      2189
# 7.0      1046
# 9.3      1015
# 9.7       922
#         ...
# 3.3        13
# 19.5       13
# 19.2       13
# 18.8       13
# 19.1       13
# Name: vis_km, Length: 63, dtype: int64

# %%
conteo_altitud.plot(kind='bar')
plt.xlabel('ALTITUD')
plt.ylabel('conteo')
plt.title('Altura mts')
# Out:
# Text(0.5, 1.0, 'Altura')

# %%
print(df_calidad_del_aire['Calidad_NO2'].mean())
print(df_calidad_del_aire['Calidad_NO2'].median())
print('valor máximo:',df_calidad_del_aire['Calidad_NO2'].max())
print('valor mínimo:',df_calidad_del_aire['Calidad_NO2'].min())
valor_maximo = df_calidad_del_aire['Calidad_NO2'].max()
valor_minimo = df_calidad_del_aire['Calidad_NO2'].min()
rango = valor_maximo-valor_minimo
print('rango: ',rango)
print('Promedio: ', df_calidad_del_aire['Calidad_NO2'].mean())
print('Media: ', df_calidad_del_aire['Calidad_NO2'].median())
rango = df_calidad_del_aire['Calidad_NO2'].max () - df_calidad_del_aire['Calidad_NO2'].min()
print('Rango: ', rango)
print('Varianza: ', np.var(df_calidad_del_aire['Calidad_NO2']))
print('Desviación Estándar: ', np.std(df_calidad_del_aire['Calidad_NO2']))
print('Valor máximo', df_calidad_del_aire['Calidad_NO2'].max())
print('Valor mínimo', df_calidad_del_aire['Calidad_NO2'].min())

#Histograma
Data = df_calidad_del_aire.iloc[:,5]
plt.figure()
data = np.array(Data)
fig, ax = plt.subplots()
ax.set_title('Histograma')
ax.set_ylabel('frecuencia')
ax.set_xlabel('Distrito')
plt.hist(data,bins = 5)
plt.show

#Caja Bigote
plt.figure()
fig,ax = plt.subplots()
ax.set_title('Diagrama caja Bigote')
plt.boxplot(df_calidad_del_aire['Calidad_NO2'].dropna())
# Out:
# 49.07984763443808
# 43.0
# valor máximo: 349.0
# valor mínimo: 1.0
# rango:  348.0
# Promedio:  49.07984763443808
# Media:  43.0
# Rango:  348.0
# Varianza:  1170.7586841616435
# Desviación Estándar:  34.216351122842475
# Valor máximo 349.0
# Valor mínimo 1.0
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f480dc7f3d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f480dc7f910>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f480dc7f130>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f480dc7fe50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f480dcd4130>],
#  'means': []}
